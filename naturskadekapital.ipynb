# %% [markdown]
# <a href="https://colab.research.google.com/github/eirikngard/Eika/blob/master/naturskadekapital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = np.array([18, 27, 65, 66, 80, 98, 121, 145, 114, 88, 84, 78, 57, 70, 84, 105, 126])
year = np.arange(2003,2020,1)

# %%
len(year)
# Out:
# 17

# %%
import matplotlib.pyplot as plt

plt.ylabel("naturskadekapital, mill.")
plt.plot(year, data), plt.grid(), plt.show()
# Out:
# ([<matplotlib.lines.Line2D at 0x7f138038c7f0>], None, None)

# %% [markdown]
# # Enkel lineær regresjon.
# Viser en lineær trend i naturskadekapital

# %%
def linreg(X, Y):
    """
    return a,b in solution to y = ax + b such that root mean square distance between trend line and original points is minimized
    """
    N = len(X)
    Sx = Sy = Sxx = Syy = Sxy = 0.0
    for x, y in zip(X, Y):
        Sx = Sx + x
        Sy = Sy + y
        Sxx = Sxx + x*x
        Syy = Syy + y*y
        Sxy = Sxy + x*y
    det = Sxx * N - Sx * Sx
    return (Sxy * N - Sy * Sx)/det, (Sxx * Sy - Sx * Sxy)/det


x = data
a,b = linreg(range(len(x)),x)  #//your x,y are switched from standard notation
extrapolatedtrendline=[a*index + b for index in range(len(year))] #20 is years, change after desire.

plt.plot(year,extrapolatedtrendline)
plt.plot(year,data)
plt.grid()
plt.show()
